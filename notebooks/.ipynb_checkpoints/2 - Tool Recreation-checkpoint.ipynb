# %% [markdown]
# # 2 - Tool Recreation
#
# This notebook shows a GUI recreation with the morphing parameters present on the sms-tools:
# - Harmonic Frequencies
# - Harmonic Magnitudes
# - Stochastic Component
#
# To make it work you first must to load the sounds in order to recover the harmonic analysis data from the ".had" files, previously generated with the sound analysis tool. Once the data is loaded you are able to play with these three parameters to apply different types of morphing to the two sound files.
#
# <br>
#
# If you want so see in detail the implementation of this GUI and it's interaction with the sms-tools you can check the [recreation GUI component file](/edit/project/components/gui/recreation.py)

# %%
# NOTE: Run this cell and play the "silence" sample below if you can't hear the play buttons
from IPython.display import (Audio, display, clear_output)
display(Audio('../data/sounds/silence.wav', autoplay=True))
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import components.gui.recreation
# Out:
# GridBox(children=(HTML(value="<center style='color:#b1bed6;font-size:1.6em;overflow:hidden'>Sound Moprhing</ce…
